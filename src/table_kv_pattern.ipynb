# %%
import key 
import importlib

importlib.reload(key)

def read_file(file):
    data = []
    with open(file, 'r') as file:
        # Iterate over each line in the file
        for line in file:
            # Print the line (you can replace this with other processing logic)
            data.append(line.strip())
    return data

def format(lst):
    l = []
    for v in lst:
        l.append(v.lower().strip())
    return l

# %%
root_path = '/Users/yiminglin/Documents/Codebase/Pdf_reverse'
tested_paths = []
tested_paths.append(root_path + '/data/raw/complaints & use of force/Champaign IL Police Complaints/Investigations_Redacted.pdf')
tested_paths.append(root_path + '/data/raw/complaints & use of force/UIUC PD Use of Force/22-274.releasable.pdf')
tested_paths.append(root_path + '/data/raw/certification/CT/DecertifiedOfficersRev_9622 Emilie Munson.pdf')
tested_paths.append(root_path + '/data/raw/certification/IA/Active_Employment.pdf')
tested_paths.append(root_path + '/data/raw/certification/MT/RptEmpRstrDetail Active.pdf')
tested_paths.append(root_path + '/data/raw/certification/VT/Invisible Institue Report.pdf')

tested_id = 0 #starting from 0

path = tested_paths[tested_id]
result_path = key.get_result_path(path)
truth_path = key.get_truth_path(path,1)
extracted_path = key.get_extracted_path(path)


truths = format(read_file(truth_path))
results = format(read_file(result_path))
phrases = format(read_file(extracted_path))

# %%
first_key = 'null'
for p in phrases:
    if(p == first_key):#check the first record
        break
    if(p in truths):
        print('K',p)
        if(first_key == 'null'):
            first_key = p
    else:
        print('V',p)
# Out:
# V report criteria
# V complaints occurred between
# V 1/1/2008 and 11/20/2020
# V complaints detail rpt #a-2
# V champaign police department
# K date
# K number
# K investigator
# K date assigned
# K racial
# K category / type
# K location of occurrence
# K disposition
# K completed
# K recorded on camera
# V 1/27/2008
# V 08-01
# V swenson, jon
# V no
# V formal
# V not stated
# V sustained
# V no
# V 1/30/2008
# V citizen
# V 2/7/2008
# V n/a
# K complainant
# K dob
# K gender
# V femal
# K address
# V terr, champaign il 61820
# K h phone
# K type of complaint
# K description
# K complaint disposition
# K complaint #
# V 1
# V r-3b.1 courtesy
# V profanity
# V discourteous conduct
# V sustained
# K name
# K id no.
# K rank
# K division
# K officer disposition
# K action taken
# K body cam
# K officer #
# V 1
# V griffet, david i.
# V 914
# V sergeant
# V field operations
# V sustained
# V counseling
# V no

# %%
root_path = '/Users/yiminglin/Documents/Codebase/Pdf_reverse'
tested_paths = []
tested_paths.append(root_path + '/data/raw/complaints & use of force/Champaign IL Police Complaints/Investigations_Redacted.pdf')
tested_paths.append(root_path + '/data/raw/complaints & use of force/UIUC PD Use of Force/22-274.releasable.pdf')
tested_paths.append(root_path + '/data/raw/certification/CT/DecertifiedOfficersRev_9622 Emilie Munson.pdf')
tested_paths.append(root_path + '/data/raw/certification/IA/Active_Employment.pdf')
tested_paths.append(root_path + '/data/raw/certification/MT/RptEmpRstrDetail Active.pdf')
tested_paths.append(root_path + '/data/raw/certification/VT/Invisible Institue Report.pdf')

tested_id = 1 #starting from 0

path = tested_paths[tested_id]
result_path = key.get_result_path(path)
truth_path = key.get_truth_path(path,1)
extracted_path = key.get_extracted_path(path)


truths = format(read_file(truth_path))
results = format(read_file(result_path))
phrases = format(read_file(extracted_path))

first_key = 'null'
for p in phrases:
    if(p == first_key):#check the first record
        break
    if(p in truths):
        print('K',p)
        if(first_key == 'null'):
            first_key = p
    else:
        print('V',p)
# Out:
# V report criteria
# V incidents between
# V 1/1/2021 and 12/31/2021
# K officer detail reports #a-12
# K university of illinois police department
# V page 1 of 27
# K case number
# V 21-00017
# K date
# V 1/15/2021
# K time
# V 1143
# K assist
# V yes
# K agency
# V sctf
# K information taken from
# V crime/ incident
# K status
# V completed
# K incident reviewed by
# V ahart, rachael f.
# K date reviewed
# V 1/15/2021
# K drugs/alcohol
# V no
# K location
# V 1609 valley road apt. d1
# K city
# V champaign
# K k-9
# V no
# K crisis intervention related
# V no
# K type premises
# V apartment
# K district
# K recorded on camera
# V yes
# K camera
# V body camera
# K type situation
# V search warrant
# K reason force used
# V fled scene
# K officer injured
# V no
# K danger factors
# V not listed
# K final disposition
# V not listed
# K verbal de-escalation attempted
# V no
# K notes
# V entered on 4/6/2021 9:55:14 am by jbclark.
# K subject #
# V 1
# V harvey, jamir t.
# K dob
# K gender
# V male
# K race
# K hgt
# V /
# K wgt
# K under the influence
# V no
# K address
# V 1609 valley road apt. d1
# K city
# V champaign
# K level of resistance
# V fleeing suspect
# K subject armed with
# V n/a
# K force used
# V fleeing
# K force location
# V not stated
# K arrested
# V yes
# K arrested for
# V not stated
# K arrest id
# V none
# K injured
# V no
# K type injuries
# K medical aid
# V no notes
# K officer
# V snow, ryan s.
# K action taken
# V firearm - pointed at subject
# K action taken useful
# V yes
# K camera
# V yes
# K cit
# V no
# K type injuries
# V none
# K disciplinary action
# V none
# K included on alert
# V yes
# K narrative
# V officers from the street crimes task force executed a search warrant and subject fled from scene.
# V officers pursued on foot and officer snow located subject in a
# V parking lot.
# V officer snow pointed firearm at the suspect and directed him to get on the ground and suspect complied.
# V suspect was taken into custody without further
# V incident.
# V l.e.a. data technologies
# V administrative database
# V 3/14/2022 8:27:19 am
# V page 1 of 27

# %%
#predicted label
pL = []
tL = []
first_key = 'null'
for p in phrases:
    if(p == first_key):#check the first record
        break
    if(p in results):
        pL.append('K')
    else:
        pL.append('V')

    if(p in truths):
        tL.append('K')
        if(first_key == 'null'):
            first_key = p
    else:
        tL.append('V')
print(pL)
print(tL)

for i in range(len(pL)):
    if(i<len(pL)-1 and pL[i] == 'K' and pL[i+1] == 'V'):
        if(tL[i] != 'K'):
            print(phrases[i])
        if(tL[i+1]!='V'):
            print(phrases[i+1])
# Out:
# ['V', 'V', 'V', 'K', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'K', 'K', 'K', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'K', 'V', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'K', 'K', 'V', 'K', 'K', 'K', 'V', 'K', 'V', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'V', 'V', 'K', 'V', 'K', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V']
# ['V', 'V', 'V', 'K', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'V', 'K', 'K', 'V', 'K', 'K', 'V', 'K', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'K', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V']
# 1

# %%
root_path = '/Users/yiminglin/Documents/Codebase/Pdf_reverse'
tested_paths = []
tested_paths.append(root_path + '/data/raw/complaints & use of force/Champaign IL Police Complaints/Investigations_Redacted.pdf')
tested_paths.append(root_path + '/data/raw/complaints & use of force/UIUC PD Use of Force/22-274.releasable.pdf')
tested_paths.append(root_path + '/data/raw/certification/CT/DecertifiedOfficersRev_9622 Emilie Munson.pdf')
tested_paths.append(root_path + '/data/raw/certification/IA/Active_Employment.pdf')
tested_paths.append(root_path + '/data/raw/certification/MT/RptEmpRstrDetail Active.pdf')
tested_paths.append(root_path + '/data/raw/certification/VT/Invisible Institue Report.pdf')

tested_id = 2 #starting from 0

path = tested_paths[tested_id]
result_path = key.get_result_path(path)
truth_path = key.get_truth_path(path,1)
extracted_path = key.get_extracted_path(path)


truths = format(read_file(truth_path))
results = format(read_file(result_path))
phrases = format(read_file(extracted_path))

first_key = 'null'
for p in phrases:
    if(p == first_key):#check the first record
        break
    if(p in truths):
        print('K',p)
        if(first_key == 'null'):
            first_key = p
    else:
        print('V',p)
# Out:
# K list of decertified officers by
# K police officer standards and training council
# K and predecessor
# K municipal police training council
# K year
# K name
# K department
# K post id#
# K date
# K reason
# V 2022
# V harris, austin g.
# V old saybrook police department
# V 18077
# V 1/7/2022
# V misconduct
# V singh, taranjit
# V norwalk police department
# V 15768
# V 3/10/2022
# V misconduct
# V dimeglio, michael
# V norwalk police department
# V 15171
# V 3/10/2022
# V misconduct
# V laudano, sara
# V norwalk police department
# V 16619
# V 3/10/2022
# V misconduct
# V acheychek, jeffrey
# V wallingford police department
# V 16085
# V 1/13/2022
# V misconduct
# V 2021
# V gamarra, gary
# V new haven police department
# V 16942
# V 11/18/2021
# V misconduct
# V perez, armando j.
# V bridgeport police department
# V 2126
# V 11/18/2021
# V felony conviction
# V carrano, john
# V bridgeport police department
# V 15034
# V 3/11/2021
# V felony conviction
# V torniero, justin
# V hartford police department
# V 13930
# V 3/11/2021
# V felony conviction
# V 2019
# V hudson, richard, t.
# V guilford police department
# V 15108
# V 6/17/2019
# V felony conviction
# V kelly, bryan, w.
# V hamden police department
# V 10403
# V 1/17/2019
# V felony conviction
# V 2018
# V dichiara, mark j.
# V newington police department
# V 8048
# V 1/18/2018
# V felony conviction
# V longolucco, jaime
# V norwich police department
# V 10404
# V 1/18/2018
# V felony conviction
# V rilling, stephen, j
# V fairfield police department
# V 10283
# V 9/13/2018
# V drug conviction
# V 2017
# V gibbs, leighton h.
# V meriden police department
# V 10218
# V 1/12/2017
# V felony conviction (worker's comp fraud)
# V 2016
# V bryant, iii, charles m.
# V new haven police department
# V 16286
# V 1/14/2016
# V falsifying police officer application
# V dunbar, jermaine d.
# V waterbury police department
# V 12480
# V 5/12/2016
# V making false statements
# V (department findings)
# V any police officer ... whose certification is cancelled or revoked pursuant to ct general statute 7-294d(23)(2) may reapply for certification no sooner than two years after the date on which
# V the cancellation or revocation order becomes final.

# %%
root_path = '/Users/yiminglin/Documents/Codebase/Pdf_reverse'
tested_paths = []
tested_paths.append(root_path + '/data/raw/complaints & use of force/Champaign IL Police Complaints/Investigations_Redacted.pdf')
tested_paths.append(root_path + '/data/raw/complaints & use of force/UIUC PD Use of Force/22-274.releasable.pdf')
tested_paths.append(root_path + '/data/raw/certification/CT/DecertifiedOfficersRev_9622 Emilie Munson.pdf')
tested_paths.append(root_path + '/data/raw/certification/IA/Active_Employment.pdf')
tested_paths.append(root_path + '/data/raw/certification/MT/RptEmpRstrDetail Active.pdf')
tested_paths.append(root_path + '/data/raw/certification/VT/Invisible Institue Report.pdf')

tested_id = 3 #starting from 0

path = tested_paths[tested_id]
result_path = key.get_result_path(path)
truth_path = key.get_truth_path(path,1)
extracted_path = key.get_extracted_path(path)


truths = format(read_file(truth_path))
results = format(read_file(result_path))
phrases = format(read_file(extracted_path))

first_key = 'null'
for p in phrases:
    if(p == first_key):#check the first record
        break
    if(p in truths):
        print('K',p)
        if(first_key == 'null'):
            first_key = p
    else:
        print('V',p)
# Out:
# V 020936
# V m
# V -1983
# V 35
# V peace officer
# V 

# %%
root_path = '/Users/yiminglin/Documents/Codebase/Pdf_reverse'
tested_paths = []
tested_paths.append(root_path + '/data/raw/complaints & use of force/Champaign IL Police Complaints/Investigations_Redacted.pdf')
tested_paths.append(root_path + '/data/raw/complaints & use of force/UIUC PD Use of Force/22-274.releasable.pdf')
tested_paths.append(root_path + '/data/raw/certification/CT/DecertifiedOfficersRev_9622 Emilie Munson.pdf')
tested_paths.append(root_path + '/data/raw/certification/IA/Active_Employment.pdf')
tested_paths.append(root_path + '/data/raw/certification/MT/RptEmpRstrDetail Active.pdf')
tested_paths.append(root_path + '/data/raw/certification/VT/Invisible Institue Report.pdf')

tested_id = 5 #starting from 0

path = tested_paths[tested_id]
result_path = key.get_result_path(path)
truth_path = key.get_truth_path(path,1)
extracted_path = key.get_extracted_path(path)


truths = format(read_file(truth_path))
results = format(read_file(result_path))
phrases = format(read_file(extracted_path))

first_key = 'null'
for p in phrases:
    if(p == first_key):#check the first record
        break
    if(p in truths):
        print('K',p)
        if(first_key == 'null'):
            first_key = p
    else:
        print('V',p)
# Out:
# K aug 19,2019
# K vt
# K criminal
# K justice
# K training
# K council
# K page
# K 1
# K 07:41am
# K employee
# K history
# K employee training
# V aamodt,
# V michael
# V j.
# V certification
# K date
# K status
# K certified
# K expires
# K probation
# K cert #
# V law enforcement level iii / certified
# V 7-01-2015
# K certified
# V 11-18-1994
# V mja2024
# V law enforcement full-time
# V 11-18-1994
# V lapsed
# V 11-18-1994
# V 7-01-2015
# V 001160
# V law enforcement part-time
# V 4-04-1994
# V lapsed
# V 3-29-1994
# V 001579
# V employment history
# V vt state police
# K service
# V 2
# V years
# V 306
# V days
# K date
# V 10-16-2016
# K action
# V transfer
# K status
# V active
# V full-time
# K assignment
# V st albans barracks
# K pos/rank
# V sergeant
# K level
# K class
# V level iii
# K shift
# V vt state police
# K service
# V 3
# V years
# V 151
# V days
# K date
# V 5-19-2013
# K action
# V promotion
# K status
# V active
# K assignment
# K pos/rank
# V detective sergeant
# K level
# K class
# V full-time
# K shift
# V vt state police
# K service
# K 1
# V years
# V 183
# V days
# K date
# V 11-18-2011
# K action
# V promotion
# K status
# V active
# K assignment
# K pos/rank
# V sergeant
# K level
# K class
# V full-time
# K shift
# V grafton fire & rescue
# K service
# V 11
# V years
# V 109
# V days
# K date
# V 5-01-2008
# K action
# V appointed
# K status
# V active
# K assignment
# K pos/rank
# K level
# K class
# K shift
# V vt state police
# K service
# V 15
# V years
# V 28
# V days
# K date
# V 10-21-1996
# K action
# V appointed
# K status
# V active
# K assignment
# K pos/rank
# V trooper
# K level
# K class
# V full-time
# K shift
# V franklin county sheriff's department
# K date
# V 10-21-1996
# K action
# V terminated (not specified)
# K status
# V inactive
# K assignment
# K pos/rank
# V deputy
# K level
# K class
# K shift
